# %%
import pandas as pd
import folium

# Load your CSV
df = pd.read_csv("../datasets/raw/London stations.csv")

# Create a base map centred roughly on London
m = folium.Map(location=[51.5074, -0.1278], zoom_start=11)

# Loop through each station and add a dot
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=4,
        color="blue",
        fill=True,
        fill_opacity=0.7,
        popup=row["Station"]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5ec269d101948624686d17c37fc8319 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5ec269d101948624686d17c37fc8319&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5ec269d101948624686d17c37fc8319 = L.map(
#                 &quot;map_a5ec269d101948624686d17c37fc8319&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aeb1e5fe0e940966e220fce8fa83a2fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aeb1e5fe0e940966e220fce8fa83a2fe.addTo(map_a5ec269d101948624686d17c37fc8319);
#
#
#             var circle_marker_66e155b2b58076d6a8e45ef35e2ddc1e = L.circleMarker(
#                 [51.53195199547294, 0.0037233710983363],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a5ec269d101948624686d17c37fc8319);
#
#
#         var popup_69adab9893df8d5318a59aba391e57cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5db591fb6b29c9660b997ba1889a8d2 = $(`&lt;div id=&quot;html_f5db591fb6b29c9660b997ba1889a8d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey Road&lt;/div&gt;`)[0];
#                 popup_69adab9893df8d5318a59aba391e57cc.setContent(html_f5db591fb6b29c9660b997ba1889a8d2);
#
#
#
#         circle_marker_66e155b2b58076d6a8e45ef35e2ddc1e.bindPopup(popup_69adab9893df8d5318a59aba391e57cc)
#         ;
#
#
#
#
#             var circle_marker_7b0c133ece235319de5e236614893850 = L.circleMarker(
#                 [51.49078429543708, 0.1202719706406512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a5ec269d101948624686d17c37fc8319);
#
#
#         var popup_79ae621bf7bec0f9231f235cb7a629f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_155e447c6c0246a8cc14fb685106554b = $(`&lt;div id=&quot;html_155e447c6c0246a8cc14fb685106554b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey Wood&lt;/div&gt;`)[0];
#                 popup_79ae621bf7bec0f9231f235cb7a629f0.setContent(html_155e447c6c0246a8cc14fb685106554b);
#
#
#
#         circle_marker_7b0c133ece235319de5e236614893850.bindPopup(popup_79ae621bf7bec0f9231f235cb7a629f0)
#         ;
#
#
#
#
#             var circle_marker_d9d5f0fe4c751221cc385d07cf4b09ba = L.circleMarker(
#                 [51.508757351253415, -0.2634301953256889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a5ec269d101948624686d17c37fc8319);
#
#
#         var popup_0fa4fc8afd20db012b062bcf823bd50e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adbefbf0afdc0d9608cad1bd05643653 = $(`&lt;div id=&quot;html_adbefbf0afdc0d9608cad1bd05643653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acton Central&lt;/div&gt;`)[0];
#                 popup_0fa4fc8afd20db012b062bcf823bd50e.setContent(html_adbefbf0afdc0d9608cad1bd05643653);
#
#
#
#         circle_marker_d9d5f0fe4c751221cc385d07cf4b09ba.bindPopup(popup_0fa4fc8afd20db012b062bcf823bd50e)
#         ;
#
#
#
#
#             var circle_marker_0778

# %%
import pandas as pd
import folium

df = pd.read_csv("../datasets/raw/London stations.csv")

# Drop rows where Zone is missing
df = df.dropna(subset=["Zone"])

# Extract the first zone (handles "3" and "3,4,5,6")
df["Zone"] = df["Zone"].astype(str).str.split(",").str[0].astype(int)

zone_colors = {
    1: "red",
    2: "orange",
    3: "green",
    4: "blue",
    5: "purple",
    6: "pink",
    7: "brown"
}

m = folium.Map(location=[51.5074, -0.1278], zoom_start=11)

for _, row in df.iterrows():
    zone = row["Zone"]
    color = zone_colors.get(zone, "black")

    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=f"{row['Station']} (Zone {zone})"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b61a5b772595e80b075f2d9be1dd515 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b61a5b772595e80b075f2d9be1dd515&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b61a5b772595e80b075f2d9be1dd515 = L.map(
#                 &quot;map_0b61a5b772595e80b075f2d9be1dd515&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c6c8bcdf2459220a1fa6e5286d8f7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6c6c8bcdf2459220a1fa6e5286d8f7d.addTo(map_0b61a5b772595e80b075f2d9be1dd515);
#
#
#             var circle_marker_b5803f235b4bf2f7d659ea558c4fd27a = L.circleMarker(
#                 [51.53195199547294, 0.0037233710983363],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b61a5b772595e80b075f2d9be1dd515);
#
#
#         var popup_877e11c55dacaeb70ee7ff78a5947089 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38e565e995170c5a9096f1c98ae43bc2 = $(`&lt;div id=&quot;html_38e565e995170c5a9096f1c98ae43bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey Road (Zone 3)&lt;/div&gt;`)[0];
#                 popup_877e11c55dacaeb70ee7ff78a5947089.setContent(html_38e565e995170c5a9096f1c98ae43bc2);
#
#
#
#         circle_marker_b5803f235b4bf2f7d659ea558c4fd27a.bindPopup(popup_877e11c55dacaeb70ee7ff78a5947089)
#         ;
#
#
#
#
#             var circle_marker_e326453764e5e77fc4fdcbb19e4a3964 = L.circleMarker(
#                 [51.49078429543708, 0.1202719706406512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b61a5b772595e80b075f2d9be1dd515);
#
#
#         var popup_157b7c20f33a81f9edb2f6347575d621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfd0e58ccc82447bcfc6244424c4ce7d = $(`&lt;div id=&quot;html_bfd0e58ccc82447bcfc6244424c4ce7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abbey Wood (Zone 4)&lt;/div&gt;`)[0];
#                 popup_157b7c20f33a81f9edb2f6347575d621.setContent(html_bfd0e58ccc82447bcfc6244424c4ce7d);
#
#
#
#         circle_marker_e326453764e5e77fc4fdcbb19e4a3964.bindPopup(popup_157b7c20f33a81f9edb2f6347575d621)
#         ;
#
#
#
#
#             var circle_marker_1b0cf5492efa2677bceec5b4b10409ad = L.circleMarker(
#                 [51.508757351253415, -0.2634301953256889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b61a5b772595e80b075f2d9be1dd515);
#
#
#         var popup_1f9d93f51a22b953bf31a5e0a982756d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23b81db68e8ad6ff10d8bcf2bade1688 = $(`&lt;div id=&quot;html_23b81db68e8ad6ff10d8bcf2bade1688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acton Central (Zone 2)&lt;/div&gt;`)[0];
#                 popup_1f9d93f51a22b953bf31a5e0a982756d.setContent(html_23b81db68e8ad6ff10d8bcf2bade1688);
#
#
#
#         circle_marker_1b0cf5492efa2677bceec5b4b10409ad.bindPopup(popup_1f9d93f51a22b953bf31a5e0a982756d)
#         ;
